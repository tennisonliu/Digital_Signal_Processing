# %% [markdown]
# ## ELEC3305 Lab 2 -  DTFT <br> <small> Python Lab 2 </small>

# %% [markdown]
# ### DTFT:

# %% [markdown]
# In this part of the lab, we will look at the DTFT of rectangular windows and triangular windows and compare their performances as low-pass filters. There is a code template provided for each part to help you become familiar with numpy syntax.

# %% [markdown]
# ### Part (a):

# %%
#Import libraries
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Plot the DTFT (at least 512 points) of the rectangular window:
#
# <center>$$ w[n] = \left \{ \begin{array}{cc} 1 & -N \leq n \leq N \\ 0 & \mathrm{otherwise} \end{array} \right. $$ </center>
#
# for $ N=5,~20,~100$. Scale the DTFT so that $W(e^{j0})=1$ in your plots. Label your plots!
#
# Describe the effect of increasing $N$ on the DTFT.
#
# A code template is provided for each part

# %% [markdown]
# ### Solution for (a):

# %%
#Import libraries
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

M = 1024 
    #repeat for N = 5, 20, 100
index = 0
for N in [5, 20, 100]:  
    index += 1
    # create 2N+1-point temporal indices (NN) from -N to N using np.r_
    NN = np.r_[-N:N+1]

    # create rectangular window function (w[n]) using np.ones
    w = np.ones(NN.shape)

    # create M-point frequency indices (Omega) from -pi to pi (use np.pi)
    Omega = np.linspace(-np.pi,np.pi,M)

    # create matrix of appropriate temporal indices (n) and frequency indices (omega) using np.outer
    Wmat = np.outer(NN,Omega)

    # create DTFT matrix using np.exp
    DTFT = np.exp(-1j*Wmat)

    # evaluate DTFT using np.dot function
    ### FILL IN ###
    w = np.dot(w,DTFT)


    # normalize W such that W at omega=0 is 1 (use np.divide and np.amax)
    ### FILL IN ###
    #Scale the DTFT so that 𝑊(𝑒.^𝑗0)=1

    max_w = np.amax(w)

    w = np.divide(w, max_w)

    # create plots
    # plot both real and imag on the same figure using subplots ( use W.real and W.imag )
    # label plots and put title and legends ( use plt.xlabel, plt.title, plt.legend )
    ### FILL IN ###
    plt.figure(index)

    plt.subplot(211)
    plt.plot(Omega,w.real)
    plt.xlabel( "Radians" )
    plt.ylabel( "W.real" )
    plt.title( "Real Part N = {}".format(N) )

    plt.subplot(212)
    plt.plot(Omega,w.imag)
    plt.xlabel( "Radians" )
    plt.ylabel( "W.imag" ) 
    #plt.legend( ("N=5","N=20","N=100") )
    plt.title( "Imaginary Part N = {}".format(N) )

# %% [markdown]
# Describe the effect of increasing $N$ on the DTFT:
#
# Solution:
#
# As N increases, the width of the mainlobe decreases.
# The width of the transition region between passband and stopband decreases as well.
#
# ----

# %% [markdown]
# ### Part (b):

# %% [markdown]
# Repeat part (a) for the triangular window:
# $$w_\triangle [n] =  \left ( 1- \frac{|n|}{N} \right ) w[n].$$

# %% [markdown]
# ### Solution for (b):

# %%
#Import libraries
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
M = 1024

index = 0
    #repeat for N = 5, 20, 100
for N in [5, 20, 100]:  
    index += 1
        # create 2N+1-point temporal indices (NN) from -N to N using np.r_
        ### FILL IN ###
    NN = np.r_[-N:N+1]
        
        # create window function (w) 
        ### FILL IN ###
    w = (1-abs(NN)/N)*np.ones(NN.shape)
        
        # create 512-point frequency indices (Omega) from -pi to pi (use np.pi)
        ### FILL IN ###
    Omega = np.linspace(-np.pi,np.pi,512)
        
        # create matrix of appropriate temporal indices (n) and frequency indices (omega) using np.outer
        ### FILL IN ###
    Wmat = np.outer(NN,Omega)
        
        
        # create DTFT matrix using np.exp
        ### FILL IN ###
    DTFT = np.exp(-1j*Wmat)
        
        # evaluate DTFT using dot function
        ### FILL IN ###
    w = np.dot(w,DTFT)
         
        # normalize W such that W at omega=0 is 1 (use np.divide and np.amax)
        ### FILL IN ###
        
    max_w = np.amax(w)

    w = np.divide(w, max_w)
        
        # create plots
        # plot both real and imag on the same figure using subplots (use W.real and W.imag )
        # label plots and put title and legends ( use plt.xlabel, plt.title, plt.legend )
        ### FILL IN ###
    plt.figure(index)

    plt.subplot(211)
    plt.plot(Omega,w.real)
    plt.xlabel( "Radians" )
    plt.ylabel( "W.real" )
    plt.title( "Real Part N = {}" .format(N))

    plt.subplot(212)
    plt.plot(Omega,w.imag)
    plt.xlabel( "Radians" )
    plt.ylabel( "W.imag" ) 
    plt.title( "Imaginary Part N = {}".format(N) )

# %% [markdown]
# Describe the effect of increasing $N$ on the DTFT:
#
# Solution:
#
# As N increases, the width of the mainlobe decreases.
# The width of the transition region between passband and stopband decreases as well.
#
# ----

# %% [markdown]
# ### Part (c):

# %% [markdown]
# Consider the ideal low-pass filter with cut-off frequency $\omega_c = 0.3 \pi$. Truncate the impulse response of this filter using the windows in parts (a) and (b), and plot the frequency response of the resulting filters. Explain the differences.

# %% [markdown]
# ### Solution for (c):

# %%
#Import libraries
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# using the window function in part(a)
M = 1024
Omegac = 0.3*np.pi

index = 0
#repeat for N = 5, 20, 100
for N in [5, 20, 100]:  
    index += 1
    # create 2N+1-point temporal indices (NN) from -N to N using np.r_
    ### FILL IN ###
    NN = np.r_[-N:N+1]
        
    # create window function (w)
    ### FILL IN ###
    
    w_n = np.ones(2*N+1)
    w = w_n * np.sinc(Omegac*(NN))*Omegac/np.pi

    # create 512-point frequency indices (Omega) from -pi to pi (use np.pi)
    ### FILL IN ###
    Omega = np.linspace(-np.pi,np.pi,512)
            
    # create matrix of appropriate temporal indices (n) and frequency indices (omega) using np.outer
    ### FILL IN ###
    Wmat = np.outer(NN,Omega)    
        
    # create DTFT matrix using np.exp
        ### FILL IN ###
    DTFT = np.exp(-1j*Wmat)    
        
    # evaluate DTFT using dot function
    ### FILL IN ###
    w = np.dot(w,DTFT)    
         
    # normalize W such that W at omega=0 is 1 (use np.divide and np.amax)
        ### FILL IN ###
        
    max_w = np.amax(w)

    w = np.divide(w, max_w)
           
        # create plots
        # plot both real and imag on the same figure ( use W.real and W.imag )
        # label plots and put title and legends ( use plt.xlabel, plt.title, plt.legend )
        ### FILL IN ###
    plt.figure(index)

    plt.subplot(211)
    plt.plot(Omega,w.real)
    plt.xlabel( "Radians" )
    plt.ylabel( "W.real" )
    plt.title( "Real Part N = {}".format(N))

    plt.subplot(212)
    plt.plot(Omega,w.imag)
    plt.xlabel( "Radians" )
    plt.ylabel( "W.imag" ) 
    plt.title( "Imaginary Part N = {}".format(N) )

# %%
#Import libraries
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# using the window function in part(b)
M = 1024
Omegac = 0.3*np.pi

index = 0
#repeat for N = 5, 20, 100
for N in [5, 20, 100]:  
    index += 1
    # create 2N+1-point temporal indices (NN) from -N to N using np.r_
    ### FILL IN ###
    NN = np.r_[-N:N+1]
        
    # create window function (w)
    ### FILL IN ###
    
    w_n = (1-abs(NN)/N)*np.ones(NN.shape)
    w = w_n * np.sinc(Omegac*(NN))*Omegac/np.pi

    # create 512-point frequency indices (Omega) from -pi to pi (use np.pi)
    ### FILL IN ###
    Omega = np.linspace(-np.pi,np.pi,512)
            
    # create matrix of appropriate temporal indices (n) and frequency indices (omega) using np.outer
    ### FILL IN ###
    Wmat = np.outer(NN,Omega)    
        
    # create DTFT matrix using np.exp
        ### FILL IN ###
    DTFT = np.exp(-1j*Wmat)    
        
    # evaluate DTFT using dot function
    ### FILL IN ###
    w = np.dot(w,DTFT)    
         
    # normalize W such that W at omega=0 is 1 (use np.divide and np.amax)
        ### FILL IN ###
        
    max_w = np.amax(w)

    w = np.divide(w, max_w)
           
        # create plots
        # plot both real and imag on the same figure ( use W.real and W.imag )
        # label plots and put title and legends ( use plt.xlabel, plt.title, plt.legend )
        ### FILL IN ###
    plt.figure(index)

    plt.subplot(211)
    plt.plot(Omega,w.real)
    plt.xlabel( "Radians" )
    plt.ylabel( "W.real" )
    plt.title( "Real Part N = {}".format(N))

    plt.subplot(212)
    plt.plot(Omega,w.imag)
    plt.xlabel( "Radians" )
    plt.ylabel( "W.imag" ) 
    plt.title( "Imaginary Part N = {}".format(N) )

# %% [markdown]
# Difference:
#
# The DTFT of the low pass filter by using the triangular window is smoother and
# much less ripple than using the rectangular window.
